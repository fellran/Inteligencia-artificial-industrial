# %% [markdown]
# # Temperaturas de maquinas

# %%
import matplotlib.pyplot as plt

# %%
dias = list(range(1, 11))

temperatura = [68.5, 69.2, 70.1, 72.3, 73.0, 71.8, 70.5, 69.4, 68.4, 67.7]

plt.plot(dias, temperatura)
plt.title('Temperatura das maquinas (°C)')
plt.xlabel('Dias')
plt.ylabel('Temperatura')
plt.grid(True)
plt.show()

# %% [markdown]
# 	# 📊 Análise de Dados Industriais
# Neste notebook, vamos trabalhar com dados fictícios de sensores de temperatura de máquinas industriais. A ideia é simular um conjunto de medições para estruturar nosso DataFrame e fazer análises futuras

# %%
import pandas as pd # manipulação de tabelas
import matplotlib.pyplot as plt # visualização de dados

# %%
	# Criando um dicionário com os dados
dados = {
    "maquina": ["A", "A", "B", "B", "C", "C"],
    "dia": [1, 2, 1, 2, 1, 2],
    "temperatura": [68.5, 70.1, 72.3, 73.0, 71.8, 70.5]
}

# Transformando em data frame
df = pd.DataFrame(dados)

# visualizando dados
df.head()
# Out:
#   maquina  dia  temperatura
# 0       A    1         68.5
# 1       A    2         70.1
# 2       B    1         72.3
# 3       B    2         73.0
# 4       C    1         71.8

# %%
# verificando o nome das colunas
print(df.columns)

# verificando o tipo de dados de uma coluna
print(df.dtypes)
# Out:
# Index(['maquina', 'dia', 'temperatura'], dtype='object')
# maquina         object
# dia              int64
# temperatura    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   maquina      6 non-null      object
#  1   dia          6 non-null      int64
#  2   temperatura  6 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 276.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   maquina      6 non-null      object
#  1   dia          6 non-null      int64
#  2   temperatura  6 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 276.0+ bytes
